# %%
import pandas as pd

# %%
# Read the JSON data from a file
with open(r'C:\Users\roika\.jupyter\evpd.json', 'r') as json_file:
    data = json_file.read()

# Create a DataFrame from the JSON data
df = pd.read_json(data)

# Display the DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11404\4195516708.py in <module>
#       4
#       5 # Create a DataFrame from the JSON data
# ----> 6 df = pd.read_json(data)
#       7
#       8 # Display the DataFrame
#
# c:\Users\roika\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# c:\Users\roika\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import json
import pandas as pd

# Read the JSON data from a file
with open(r'C:\Users\roika\.jupyter\evpd.json', 'r') as json_file:
    data = json.load(json_file)

# Create a DataFrame from the parsed JSON data
df = pd.DataFrame(data)

# Display the DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11404\4275384147.py in <module>
#       7
#       8 # Create a DataFrame from the parsed JSON data
# ----> 9 df = pd.DataFrame(data)
#      10
#      11 # Display the DataFrame
#
# c:\Users\roika\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     661         elif isinstance(data, dict):
#     662             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664         elif isinstance(data, ma.MaskedArray):
#     665             import numpy.ma.mrecords as mrecords
#
# c:\Users\roika\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
import pandas as pd

# Read the JSON data from a file
df = pd.read_json(r'C:\Users\roika\.jupyter\evpd.json')

# Display the DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11404\2673609109.py in <module>
#       2
#       3 # Read the JSON data from a file
# ----> 4 df = pd.read_json(r'C:\Users\roika\.jupyter\evpd.json')
#       5
#       6 # Display the DataFrame
#
# c:\Users\roika\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# c:\Users\roika\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
import requests
import pandas as pd

# Make a GET request to the API
response = requests.get('https://data.wa.gov/api/views/f6w7-q2d2/rows')

# Process the response as JSON data
data = response.json()

# Extract the rows from the JSON data
rows = data['data']

# Extract the column names from the JSON metadata
column_names = [column['name'] for column in data['meta']['view']['columns']]

# Create a DataFrame from the rows and column names
df = pd.DataFrame(rows, columns=column_names)

# %%
df
# Out:
#                        sid                                    id  position  \
# 0       row-ju5t_y67a-pkpx  00000000-0000-0000-9BDE-D799A646C5F2         0
# 1       row-ddrq-f23i_tg5e  00000000-0000-0000-32BB-911748C5F0BC         0
# 2       row-29gy-3ns3_gccy  00000000-0000-0000-FF08-A80E776C6EB3         0
# 3       row-4vqg_t8jy_v46s  00000000-0000-0000-BDAD-EE4CC1703387         0
# 4       row-ri6s~b689_8wdz  00000000-0000-0000-E30A-110387DA09E6         0
# ...                    ...                                   ...       ...
# 130438  row-9yku_3qna_evfx  00000000-0000-0000-4BC9-C1730064C880         0
# 130439  row-en5d.qpkb_n3me  00000000-0000-0000-EC1D-D8549ABAA8CB         0
# 130440  row-d7b6-3usy~88zh  00000000-0000-0000-1C18-C08F7930252B         0
# 130441  row-exe7_kixc.e3jf  00000000-0000-0000-A0BC-3EC986EF519E         0
# 130442  row-d3s8-ek9b_42di  00000000-0000-0000-1571-10BA6C9617E6         0
#
# ...
